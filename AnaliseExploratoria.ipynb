# %% [markdown]
# # Importando as bibliotecas necessárias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap

from sklearn import neighbors, datasets
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

np.random.seed(42)

# %% [markdown]
# # Importando o dataset (Breast Cancer Wisconsin)

# %%
df = pd.read_csv("data/data.csv")

# Removendo colunas desnecessárias
df.drop(columns=['id', 'Unnamed: 32'], inplace=True)

print(f"Shape após a limpeza : {df.shape}")
print(f"Valores ausentes       : {df.isnull().sum().sum()}")
print(f"\nDistribuição de classes:")
vc = df['diagnosis'].value_counts()
print(f"  Benígno (B)    : {vc['B']}  ({vc['B']/len(df)*100:.1f}%)")
print(f"  Malígno (M) : {vc['M']}  ({vc['M']/len(df)*100:.1f}%)")

df.head()
# Out:
# Shape após a limpeza : (569, 31)
# Valores ausentes       : 0
#
# Distribuição de classes:
#   Benígno (B)    : 357  (62.7%)
#   Malígno (M) : 212  (37.3%)
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# ...

# %% [markdown]
# # Analise Exploratória dos dados

# %%
print("\n--- Diagnosis Target Distribution ---")
print(df['diagnosis'].value_counts())

plt.figure(figsize=(6,4))
sns.countplot(x='diagnosis', data=df, palette='Set2')
plt.title('Distribution of Diagnosis (M = Malignant, B = Benign)')
plt.show()

# %%
df.groupby('diagnosis').head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          M       17.990         10.38          122.80     1001.0
# 1          M       20.570         17.77          132.90     1326.0
# 2          M       19.690         21.25          130.00     1203.0
# 3          M       11.420         20.38           77.58      386.1
# 4          M       20.290         14.34          135.10     1297.0
# 19         B       13.540         14.36           87.46      566.3
# 20         B       13.080         15.71           85.63      520.0
# 21         B        9.504         12.44           60.34      273.9
# 37         B       13.030         18.42           82.61      523.8
# 46         B        8.196         16.84           51.71      201.9
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.11840           0.27760         0.30010             0.147100
# 1           0.08474           0.07864         0.08690             0.070170
# ...

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
plt.figure(figsize=(12, 10))
# Select only numeric columns for correlation matrix
numeric_cols = df.select_dtypes(include=[np.number]).columns
corr_matrix = df[numeric_cols].corr()

# Mask the upper triangle for better visualization
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, mask=mask, cmap='coolwarm', annot=False, fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

# %%
df.plot.scatter(x='radius_mean', y='texture_mean', c=df['diagnosis'].map({'B': 0, 'M': 1}), cmap=ListedColormap(['blue', 'red']))
df.plot.scatter(x='perimeter_mean', y='area_mean', c=df['diagnosis'].map({'B': 0, 'M': 1}), cmap=ListedColormap(['blue', 'red']))
df.plot.scatter(x='concavity_mean', y='concave points_mean', c=df['diagnosis'].map({'B': 0, 'M': 1}), cmap=ListedColormap(['blue', 'red']))

# %%
df.plot.scatter(x='radius_mean', y='texture_mean', c=df['diagnosis'].map({'B': 0, 'M': 1}), cmap=ListedColormap(['blue', 'red']))
df.plot.scatter(x='perimeter_mean', y='concave points_mean', c=df['diagnosis'].map({'B': 0, 'M': 1}), cmap=ListedColormap(['blue', 'red']))
df.plot.scatter(x='concavity_mean', y='area_mean', c=df['diagnosis'].map({'B': 0, 'M': 1}), cmap=ListedColormap(['blue', 'red']))

# %% [markdown]
# Escolhemos os valores médios na base de dados e plotamos alguns gráficos de dispersão que nos dão a entender que essas variáveis podem ser significaticas para nosso estudo
